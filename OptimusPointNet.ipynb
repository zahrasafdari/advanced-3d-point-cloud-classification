# %%
# Install necessary libraries
# !pip install torch torchvision

# Download ModelNet40 dataset (optional: You can directly upload the dataset to Google Drive or Colab)
# !wget https://modelnet.cs.princeton.edu/ModelNet40.zip
# !unzip ModelNet40.zip -d data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/ModelNet40/monitor/train/monitor_0120.off
#   inflating: data/ModelNet40/monitor/train/monitor_0199.off
#   inflating: data/ModelNet40/monitor/train/monitor_0285.off
#   inflating: data/ModelNet40/monitor/train/monitor_0227.off
#   inflating: data/ModelNet40/monitor/train/monitor_0281.off
#   inflating: data/ModelNet40/monitor/train/monitor_0067.off
#   inflating: data/ModelNet40/monitor/train/monitor_0368.off
#   inflating: data/ModelNet40/monitor/train/monitor_0090.off
#   inflating: data/ModelNet40/monitor/train/monitor_0436.off
#   inflating: data/ModelNet40/monitor/train/monitor_0137.off
#   inflating: data/ModelNet40/monitor/train/monitor_0011.off
#   inflating: data/ModelNet40/monitor/train/monitor_0288.off
#   inflating: data/ModelNet40/monitor/train/monitor_0284.off
#   inflating: data/ModelNet40/monitor/train/monitor_0325.off
#   inflating: data/ModelNet40/monitor/train/monitor_0378.off
#   inflating: data/ModelNet40/monitor/train/monitor_0171.off
#   inflating: data/ModelNet40/monitor/train/monitor_0279.off
#   inflating: data/ModelNet40/monitor/train/monitor_0104.off
#   inflating: data/ModelNet40/monitor/train/monitor_0144.off
#   inflating: data/ModelNet40/monitor/train/monitor_0377.off
#   inflating: data/ModelNet40/monitor/train/monitor_0190.off
#   inflating: data/ModelNet40/monitor/train/monitor_0402.off
#   inflating: data/ModelNet40/monitor/train/monitor_0301.off
#   inflating: data/ModelNet40/monitor/train/monitor_0411.off
#   inflating: data/ModelNet40/monitor/train/monitor_0186.off
#   inflating: data/ModelNet40/monitor/train/monitor_0445.off
#   inflating: data/ModelNet40/monitor/train/monitor_0341.off
#   inflating: data/ModelNet40/monitor/train/monitor_0039.off
#   inflating: data/ModelNet40/monitor/train/monitor_0012.off
#   inflating: data/ModelNet40/monitor/train/monitor_0340.off
#   inflating: data/ModelNet40/monitor/train/monitor_0063.off
#   inflating: data/ModelNet40/monitor/train/monitor_0074.off
#   inflating: data/ModelNet40/monitor/train/monitor_0216.off
#   inflating: data/ModelNet40/monitor/train/monitor_0018.off
#   inflating: data/ModelNet40/monitor/train/monitor_0336.off
#   inflating: data/ModelNet40/monitor/train/monitor_0205.off
#   inflating: data/ModelNet40/monitor/train/monitor_0344.off
#   inflating: data/ModelNet40/monitor/train/monitor_0385.off
#   inflating: data/ModelNet40/monitor/train/monitor_0274.off
#   inflating: data/ModelNet40/monitor/train/monitor_0215.off
#   inflating: data/ModelNet40/monitor/train/monitor_0265.off
#   inflating: data/ModelNet40/monitor/train/monitor_0292.off
#   inflating: data/ModelNet40/monitor/train/monitor_0247.off
#   inflating: data/ModelNet40/monitor/train/monitor_0140.off
#   inflating: data/ModelNet40/monitor/train/monitor_0403.off
#   inflating: data/ModelNet40/monitor/train/monitor_0235.off
#   inflating: data/ModelNet40/monitor/train/monitor_0053.off
#   inflating: data/ModelNet40/monitor/train/monitor_0091.off
#   inflating: data/ModelNet40/monitor/train/monitor_0075.off
#   inflating: data/ModelNet40/monitor/train/monitor_0423.off
#   inflating: data/ModelNet40/monitor/train/monitor_0141.off
#   inflating: data/ModelNet40/monitor/train/monitor_0338.off
#   inflating: data/ModelNet40/monitor/train/monitor_0355.off
#   inflating: data/ModelNet40/monitor/train/monitor_0259.off
#   inflating: data/ModelNet40/monitor/train/monitor_0277.off
#   inflating: data/ModelNet40/monitor/train/monitor_0152.off
#   inflating: data/ModelNet40/monitor/train/monitor_0087.off
#   inflating: data/ModelNet40/monitor/train/monitor_0303.off
#   inflating: data/ModelNet40/monitor/train/monitor_0153.off
#   inflating: data/ModelNet40/monitor/train/monitor_0286.off
#   inflating: data/ModelNet40/monitor/train/monitor_0416.off
#   inflating: data/ModelNet40/monitor/train/monitor_0047.off
#   inflating: data/ModelNet40/monitor/train/monitor_0298.off
#   inflating: data/ModelNet40/monitor/train/monitor_0172.off
#   inflating: data/ModelNet40/monitor/train/monitor_0049.off
#   inflating: data/ModelNet40/monitor/train/monitor_0032.off
#   inflating: data/ModelNet40/monitor/train/monitor_0193.off
#   inflating: data/ModelNet40/monitor/train/monitor_0241.off
#   inflating: data/ModelNet40/monitor/train/monitor_0349.off
#   inflating: data/ModelNet40/monitor/train/monitor_0461.off
#   inflating: data/ModelNet40/monitor/train/monitor_0220.off
#   inflating: data/ModelNet40/monitor/train/monitor_0415.off
#   inflating: data/ModelNet40/monitor/train/monitor_0127.off
#   inflating: data/ModelNet40/monitor/train/monitor_0086.off
#   inflating: data/ModelNet40/monitor/train/monitor_0342.off
#   inflating: data/ModelNet40/monitor/train/monitor_0404.off
#   inflating: data/ModelNet40/monitor/train/monitor_0099.off
#   inflating: data/ModelNet40/monitor/train/monitor_0122.off
#   inflating: data/ModelNet40/monitor/train/monitor_0460.off
#   inflating: data/ModelNet40/monitor/train/monitor_0050.off
#   inflating: data/ModelNet40/monitor/train/monitor_0013.off
#   inflating: data/ModelNet40/monitor/train/monitor_0036.off
#   inflating: data/ModelNet40/monitor/train/monitor_0280.off
#   inflating: data/ModelNet40/monitor/train/monitor_0054.off
#   inflating: data/ModelNet40/monitor/train/monitor_0229.off
#   inflating: data/ModelNet40/monitor/train/monitor_0223.off
#   inflating: data/ModelNet40/monitor/train/monitor_0426.off
#   inflating: data/ModelNet40/monitor/train/monitor_0084.off
#   inflating: data/ModelNet40/monitor/train/monitor_0194.off
#   inflating: data/ModelNet40/monitor/train/monitor_0294.off
#   inflating: data/ModelNet40/monitor/train/monitor_0015.off
#   inflating: data/ModelNet40/monitor/train/monitor_0319.off
#   inflating: data/ModelNet40/monitor/train/monitor_0206.off
#   inflating: data/ModelNet40/monitor/train/monitor_0420.off
#   inflating: data/ModelNet40/monitor/train/monitor_0100.off
#   inflating: data/ModelNet40/monitor/train/monitor_0400.off
#   inflating: data/ModelNet40/monitor/train/monitor_0218.off
#   inflating: data/ModelNet40/monitor/train/monitor_0083.off
#   inflating: data/ModelNet40/monitor/train/monitor_0156.off
#   inflating: data/ModelNet40/monitor/train/monitor_0429.off
#   inflating: data/ModelNet40/monitor/train/monitor_0452.off
#   inflating: data/ModelNet40/monitor/train/monitor_0136.off
#   inflating: data/ModelNet40/monitor/train/monitor_0113.off
#   inflating: data/ModelNet40/monitor/train/monitor_0160.off
#   inflating: data/ModelNet40/monitor/train/monitor_0333.off
#   inflating: data/ModelNet40/monitor/train/monitor_0458.off
#   inflating: data/ModelNet40/monitor/train/monitor_0097.off
#   inflating: data/ModelNet40/monitor/train/monitor_0418.off
#   inflating: data/ModelNet40/monitor/train/monitor_0057.off
#   inflating: data/ModelNet40/monitor/train/monitor_0408.off
#   inflating: data/ModelNet40/monitor/train/monitor_0118.off
#   inflating: data/ModelNet40/monitor/train/monitor_0076.off
#   inflating: data/ModelNet40/monitor/train/monitor_0313.off
#   inflating: data/ModelNet40/monitor/train/monitor_0237.off
#   inflating: data/ModelNet40/monitor/train/monitor_0251.off
#   inflating: data/ModelNet40/monitor/train/monitor_0178.off
#   inflating: data/ModelNet40/monitor/train/monitor_0323.off
#   inflating: data/ModelNet40/monitor/train/monitor_0163.off
#   inflating: data/ModelNet40/monitor/train/monitor_0348.off
#   inflating: data/ModelNet40/monitor/train/monitor_0266.off
#   inflating: data/ModelNet40/monitor/train/monitor_0287.off
#   inflating: data/ModelNet40/monitor/train/monitor_0457.off
#   inflating: data/ModelNet40/monitor/train/monitor_0116.off
#   inflating: data/ModelNet40/monitor/train/monitor_0312.off
#   inflating: data/ModelNet40/monitor/train/monitor_0066.off
#   inflating: data/ModelNet40/monitor/train/monitor_0358.off
#   inflating: data/ModelNet40/monitor/train/monitor_0151.off
#   inflating: data/ModelNet40/monitor/train/monitor_0132.off
#   inflating: data/ModelNet40/monitor/train/monitor_0095.off
#   inflating: data/ModelNet40/monitor/train/monitor_0080.off
#   inflating: data/ModelNet40/monitor/train/monitor_0318.off
#   inflating: data/ModelNet40/monitor/train/monitor_0380.off
#   inflating: data/ModelNet40/monitor/train/monitor_0184.off
#   inflating: data/ModelNet40/monitor/train/monitor_0046.off
#   inflating: data/ModelNet40/monitor/train/monitor_0379.off
#   inflating: data/ModelNet40/monitor/train/monitor_0393.off
#   inflating: data/ModelNet40/monitor/train/monitor_0246.off
#   inflating: data/ModelNet40/monitor/train/monitor_0356.off
#   inflating: data/ModelNet40/monitor/train/monitor_0248.off
#   inflating: data/ModelNet40/monitor/train/monitor_0146.off
#   inflating: data/ModelNet40/monitor/train/monitor_0425.off
#   inflating: data/ModelNet40/monitor/train/monitor_0422.off
#   inflating: data/ModelNet40/monitor/train/monitor_0345.off
#   inflating: data/ModelNet40/monitor/train/monitor_0072.off
#   inflating: data/ModelNet40/monitor/train/monitor_0027.off
#   inflating: data/ModelNet40/monitor/train/monitor_0434.off
#   inflating: data/ModelNet40/monitor/train/monitor_0406.off
#   inflating: data/ModelNet40/monitor/train/monitor_0042.off
#   inflating: data/ModelNet40/monitor/train/monitor_0394.off
#   inflating: data/ModelNet40/monitor/train/monitor_0249.off
#   inflating: data/ModelNet40/monitor/train/monitor_0064.off
#   inflating: data/ModelNet40/monitor/train/monitor_0101.off
#   inflating: data/ModelNet40/monitor/train/monitor_0388.off
#   inflating: data/ModelNet40/monitor/train/monitor_0372.off
#   inflating: data/ModelNet40/monitor/train/monitor_0278.off
#   inflating: data/ModelNet40/monitor/train/monitor_0419.off
#   inflating: data/ModelNet40/monitor/train/monitor_0069.off
#   inflating: data/ModelNet40/monitor/train/monitor_0366.off
#   inflating: data/ModelNet40/monitor/train/monitor_0291.off
#   inflating: data/ModelNet40/monitor/train/monitor_0123.off
#   inflating: data/ModelNet40/monitor/train/monitor_0217.off
#   inflating: data/ModelNet40/monitor/train/monitor_0310.off
#   inflating: data/ModelNet40/monitor/train/monitor_0263.off
#   inflating: data/ModelNet40/monitor/train/monitor_0062.off
#   inflating: data/ModelNet40/monitor/train/monitor_0130.off
#   inflating: data/ModelNet40/monitor/train/monitor_0232.off
#   inflating: data/ModelNet40/monitor/train/monitor_0079.off
#   inflating: data/ModelNet40/monitor/train/monitor_0430.off
#   inflating: data/ModelNet40/monitor/train/monitor_0081.off
#   inflating: data/ModelNet40/monitor/train/monitor_0365.off
#   inflating: data/ModelNet40/monitor/train/monitor_0296.off
#   inflating: data/ModelNet40/monitor/train/monitor_0315.off
#   inflating: data/ModelNet40/monitor/train/monitor_0133.off
#   inflating: data/ModelNet40/monitor/train/monitor_0363.off
#   inflating: data/ModelNet40/monitor/train/monitor_0173.off
#   inflating: data/ModelNet40/monitor/train/monitor_0239.off
#   inflating: data/ModelNet40/monitor/train/monitor_0308.off
#   inflating: data/ModelNet40/monitor/train/monitor_0307.off
#   inflating: data/ModelNet40/monitor/train/monitor_0165.off
#   inflating: data/ModelNet40/monitor/train/monitor_0297.off
#   inflating: data/ModelNet40/monitor/train/monitor_0167.off
#   inflating: data/ModelNet40/monitor/train/monitor_0327.off
#   inflating: data/ModelNet40/monitor/train/monitor_0149.off
#   inflating: data/ModelNet40/monitor/train/monitor_0008.off
#   inflating: data/ModelNet40/monitor/train/monitor_0236.off
#   inflating: data/ModelNet40/monitor/train/monitor_0085.off
#   inflating: data/ModelNet40/monitor/train/monitor_0364.off
#   inflating: data/ModelNet40/monitor/train/monitor_0421.off
#   inflating: data/ModelNet40/monitor/train/monitor_0093.off
#   inflating: data/ModelNet40/monitor/train/monitor_0126.off
#   inflating: data/ModelNet40/monitor/train/monitor_0228.off
#   inflating: data/ModelNet40/monitor/train/monitor_0431.off
#   inflating: data/ModelNet40/monitor/train/monitor_0175.off
#   inflating: data/ModelNet40/monitor/train/monitor_0243.off
#   inflating: data/ModelNet40/monitor/train/monitor_0154.off
#   inflating: data/ModelNet40/monitor/train/monitor_0253.off
#   inflating: data/ModelNet40/monitor/train/monitor_0174.off
#   inflating: data/ModelNet40/monitor/train/monitor_0198.off
#   inflating: data/ModelNet40/monitor/train/monitor_0244.off
#   inflating: data/ModelNet40/monitor/train/monitor_0094.off
#   inflating: data/ModelNet40/monitor/train/monitor_0289.off
#   inflating: data/ModelNet40/monitor/train/monitor_0225.off
#   inflating: data/ModelNet40/monitor/train/monitor_0134.off
#   inflating: data/ModelNet40/monitor/train/monitor_0180.off
#   inflating: data/ModelNet40/monitor/train/monitor_0395.off
#   inflating: data/ModelNet40/monitor/train/monitor_0396.off
#   inflating: data/ModelNet40/monitor/train/monitor_0276.off
#   inflating: data/ModelNet40/monitor/train/monitor_0373.off
#   inflating: data/ModelNet40/monitor/train/monitor_0264.off
#   inflating: data/ModelNet40/monitor/train/monitor_0110.off
#   inflating: data/ModelNet40/monitor/train/monitor_0273.off
#   inflating: data/ModelNet40/monitor/train/monitor_0343.off
#   inflating: data/ModelNet40/monitor/train/monitor_0128.off
#   inflating: data/ModelNet40/monitor/train/monitor_0314.off
#   inflating: data/ModelNet40/monitor/train/monitor_0129.off
#   inflating: data/ModelNet40/monitor/train/monitor_0440.off
#   inflating: data/ModelNet40/monitor/train/monitor_0038.off
#   inflating: data/ModelNet40/monitor/train/monitor_0014.off
#   inflating: data/ModelNet40/monitor/train/monitor_0179.off
#   inflating: data/ModelNet40/monitor/train/monitor_0346.off
#   inflating: data/ModelNet40/monitor/train/monitor_0367.off
#   inflating: data/ModelNet40/monitor/train/monitor_0125.off
#   inflating: data/ModelNet40/monitor/train/monitor_0073.off
#   inflating: data/ModelNet40/monitor/train/monitor_0017.off
#   inflating: data/ModelNet40/monitor/train/monitor_0183.off
#   inflating: data/ModelNet40/monitor/train/monitor_0433.off
#   inflating: data/ModelNet40/monitor/train/monitor_0221.off
#   inflating: data/ModelNet40/monitor/train/monitor_0390.off
#   inflating: data/ModelNet40/monitor/train/monitor_0304.off
#   inflating: data/ModelNet40/monitor/train/monitor_0234.off
#   inflating: data/ModelNet40/monitor/train/monitor_0387.off
#   inflating: data/ModelNet40/monitor/train/monitor_0397.off
#   inflating: data/ModelNet40/monitor/train/monitor_0322.off
#   inflating: data/ModelNet40/monitor/train/monitor_0035.off
#   inflating: data/ModelNet40/monitor/train/monitor_0191.off
#   inflating: data/ModelNet40/monitor/train/monitor_0383.off
#   inflating: data/ModelNet40/monitor/train/monitor_0283.off
#   inflating: data/ModelNet40/monitor/train/monitor_0166.off
#   inflating: data/ModelNet40/monitor/train/monitor_0135.off
#   inflating: data/ModelNet40/monitor/train/monitor_0437.off
#   inflating: data/ModelNet40/monitor/train/monitor_0290.off
#   inflating: data/ModelNet40/monitor/train/monitor_0028.off
#   inflating: data/ModelNet40/monitor/train/monitor_0226.off
#   inflating: data/ModelNet40/monitor/train/monitor_0459.off
#   inflating: data/ModelNet40/monitor/train/monitor_0209.off
#   inflating: data/ModelNet40/monitor/train/monitor_0158.off
#   inflating: data/ModelNet40/monitor/train/monitor_0238.off
#   inflating: data/ModelNet40/monitor/train/monitor_0450.off
#   inflating: data/ModelNet40/monitor/train/monitor_0260.off
#   inflating: data/ModelNet40/monitor/train/monitor_0398.off
#   inflating: data/ModelNet40/monitor/train/monitor_0335.off
#   inflating: data/ModelNet40/monitor/train/monitor_0424.off
#   inflating: data/ModelNet40/monitor/train/monitor_0164.off
#   inflating: data/ModelNet40/monitor/train/monitor_0115.off
#   inflating: data/ModelNet40/monitor/train/monitor_0231.off
#   inflating: data/ModelNet40/monitor/train/monitor_0428.off
#   inflating: data/ModelNet40/monitor/train/monitor_0353.off
#   inflating: data/ModelNet40/monitor/train/monitor_0058.off
#   inflating: data/ModelNet40/monitor/train/monitor_0245.off
#   inflating: data/ModelNet40/monitor/train/monitor_0444.off
#   inflating: data/ModelNet40/monitor/train/monitor_0435.off
#   inflating: data/ModelNet40/monitor/train/monitor_0334.off
#   inflating: data/ModelNet40/monitor/train/monitor_0077.off
#   inflating: data/ModelNet40/monitor/train/monitor_0262.off
#   inflating: data/ModelNet40/monitor/train/monitor_0181.off
#   inflating: data/ModelNet40/monitor/train/monitor_0329.off
#   inflating: data/ModelNet40/monitor/train/monitor_0330.off
#   inflating: data/ModelNet40/monitor/train/monitor_0055.off
#   inflating: data/ModelNet40/monitor/train/monitor_0337.off
#   inflating: data/ModelNet40/monitor/train/monitor_0309.off
#   inflating: data/ModelNet40/monitor/train/monitor_0407.off
#   inflating: data/ModelNet40/monitor/train/monitor_0026.off
#   inflating: data/ModelNet40/monitor/train/monitor_0347.off
#   inflating: data/ModelNet40/monitor/train/monitor_0092.off
#   inflating: data/ModelNet40/monitor/train/monitor_0170.off
#   inflating: data/ModelNet40/monitor/train/monitor_0413.off
#   inflating: data/ModelNet40/monitor/train/monitor_0240.off
#   inflating: data/ModelNet40/monitor/train/monitor_0392.off
#   inflating: data/ModelNet40/monitor/train/monitor_0200.off
#   inflating: data/ModelNet40/monitor/train/monitor_0417.off
#   inflating: data/ModelNet40/monitor/train/monitor_0381.off
#   inflating: data/ModelNet40/monitor/train/monitor_0354.off
#   inflating: data/ModelNet40/monitor/train/monitor_0414.off
#   inflating: data/ModelNet40/monitor/train/monitor_0112.off
#   inflating: data/ModelNet40/monitor/train/monitor_0003.off
#   inflating: data/ModelNet40/monitor/train/monitor_0105.off
#   inflating: data/ModelNet40/monitor/train/monitor_0362.off
#   inflating: data/ModelNet40/monitor/train/monitor_0201.off
#   inflating: data/ModelNet40/monitor/train/monitor_0202.off
#   inflating: data/ModelNet40/monitor/train/monitor_0438.off
#   inflating: data/ModelNet40/monitor/train/monitor_0124.off
#   inflating: data/ModelNet40/monitor/train/monitor_0109.off
#   inflating: data/ModelNet40/monitor/train/monitor_0331.off
#   inflating: data/ModelNet40/monitor/train/monitor_0142.off
#   inflating: data/ModelNet40/monitor/train/monitor_0446.off
#   inflating: data/ModelNet40/monitor/train/monitor_0212.off
#   inflating: data/ModelNet40/monitor/train/monitor_0150.off
#   inflating: data/ModelNet40/monitor/train/monitor_0056.off
#   inflating: data/ModelNet40/monitor/train/monitor_0021.off
#   inflating: data/ModelNet40/monitor/train/monitor_0060.off
#   inflating: data/ModelNet40/monitor/train/monitor_0374.off
#   inflating: data/ModelNet40/monitor/train/monitor_0051.off
#   inflating: data/ModelNet40/monitor/train/monitor_0033.off
#   inflating: data/ModelNet40/monitor/train/monitor_0350.off
#   inflating: data/ModelNet40/monitor/train/monitor_0409.off
#   inflating: data/ModelNet40/monitor/train/monitor_0360.off
#   inflating: data/ModelNet40/monitor/train/monitor_0233.off
#   inflating: data/ModelNet40/monitor/train/monitor_0108.off
#   inflating: data/ModelNet40/monitor/train/monitor_0382.off
#   inflating: data/ModelNet40/monitor/train/monitor_0162.off
#   inflating: data/ModelNet40/monitor/train/monitor_0282.off
#   inflating: data/ModelNet40/monitor/train/monitor_0213.off
#   inflating: data/ModelNet40/monitor/train/monitor_0219.off
#   inflating: data/ModelNet40/monitor/train/monitor_0119.off
#   inflating: data/ModelNet40/monitor/train/monitor_0317.off
#   inflating: data/ModelNet40/monitor/train/monitor_0114.off
#   inflating: data/ModelNet40/monitor/train/monitor_0410.off
#   inflating: data/ModelNet40/monitor/train/monitor_0103.off
#   inflating: data/ModelNet40/monitor/train/monitor_0254.off
#   inflating: data/ModelNet40/monitor/train/monitor_0339.off
#   inflating: data/ModelNet40/monitor/train/monitor_0030.off
#   inflating: data/ModelNet40/monitor/train/monitor_0040.off
#   inflating: data/ModelNet40/monitor/train/monitor_0386.off
#   inflating: data/ModelNet40/monitor/train/monitor_0034.off
#   inflating: data/ModelNet40/monitor/train/monitor_0443.off
#   inflating: data/ModelNet40/monitor/train/monitor_0048.off
#   inflating: data/ModelNet40/monitor/train/monitor_0250.off
#   inflating: data/ModelNet40/monitor/train/monitor_0252.off
#   inflating: data/ModelNet40/monitor/train/monitor_0009.off
#   inflating: data/ModelNet40/monitor/train/monitor_0224.off
#   inflating: data/ModelNet40/monitor/train/monitor_0300.off
#   inflating: data/ModelNet40/monitor/train/monitor_0203.off
#   inflating: data/ModelNet40/monitor/train/monitor_0456.off
#   inflating: data/ModelNet40/monitor/train/monitor_0023.off
#   inflating: data/ModelNet40/monitor/train/monitor_0293.off
#   inflating: data/ModelNet40/monitor/train/monitor_0432.off
#   inflating: data/ModelNet40/monitor/train/monitor_0302.off
#   inflating: data/ModelNet40/monitor/train/monitor_0161.off
#   inflating: data/ModelNet40/monitor/train/monitor_0207.off
#   inflating: data/ModelNet40/monitor/train/monitor_0185.off
#   inflating: data/ModelNet40/monitor/train/monitor_0001.off
#   inflating: data/ModelNet40/monitor/train/monitor_0321.off
#   inflating: data/ModelNet40/monitor/train/monitor_0071.off
#   inflating: data/ModelNet40/monitor/train/monitor_0176.off
#   inflating: data/ModelNet40/monitor/train/monitor_0139.off
#   inflating: data/ModelNet40/monitor/train/monitor_0107.off
#   inflating: data/ModelNet40/monitor/train/monitor_0041.off
#   inflating: data/ModelNet40/monitor/train/monitor_0025.off
#   inflating: data/ModelNet40/monitor/train/monitor_0389.off
#   inflating: data/ModelNet40/monitor/train/monitor_0138.off
#   inflating: data/ModelNet40/monitor/train/monitor_0391.off
#   inflating: data/ModelNet40/monitor/train/monitor_0197.off
#   inflating: data/ModelNet40/monitor/train/monitor_0143.off
#   inflating: data/ModelNet40/monitor/train/monitor_0059.off
#   inflating: data/ModelNet40/monitor/train/monitor_0261.off
#   inflating: data/ModelNet40/monitor/train/monitor_0106.off
#   inflating: data/ModelNet40/monitor/train/monitor_0351.off
#   inflating: data/ModelNet40/monitor/train/monitor_0016.off
#   inflating: data/ModelNet40/monitor/train/monitor_0375.off
#   inflating: data/ModelNet40/sofa/train/sofa_0493.off
#   inflating: data/ModelNet40/sofa/train/sofa_0310.off
#   inflating: data/ModelNet40/sofa/train/sofa_0353.off
#   inflating: data/ModelNet40/sofa/train/sofa_0496.off
#   inflating: data/ModelNet40/sofa/train/sofa_0267.off
#   inflating: data/ModelNet40/sofa/train/sofa_0636.off
#   inflating: data/ModelNet40/sofa/train/sofa_0265.off
#   inflating: data/ModelNet40/sofa/train/sofa_0219.off
#   inflating: data/ModelNet40/sofa/train/sofa_0036.off
#   inflating: data/ModelNet40/sofa/train/sofa_0125.off
#   inflating: data/ModelNet40/sofa/train/sofa_0292.off
#   inflating: data/ModelNet40/sofa/train/sofa_0148.off
#   inflating: data/ModelNet40/sofa/train/sofa_0484.off
#   inflating: data/ModelNet40/sofa/train/sofa_0038.off
#   inflating: data/ModelNet40/sofa/train/sofa_0447.off
#   inflating: data/ModelNet40/sofa/train/sofa_0289.off
#   inflating: data/ModelNet40/sofa/train/sofa_0296.off
#   inflating: data/ModelNet40/sofa/train/sofa_0240.off
#   inflating: data/ModelNet40/sofa/train/sofa_0056.off
#   inflating: data/ModelNet40/sofa/train/sofa_0647.off
#   inflating: data/ModelNet40/sofa/train/sofa_0521.off
#   inflating: data/ModelNet40/sofa/train/sofa_0027.off
#   inflating: data/ModelNet40/sofa/train/sofa_0079.off
#   inflating: data/ModelNet40/sofa/train/sofa_0327.off
#   inflating: data/ModelNet40/sofa/train/sofa_0300.off
#   inflating: data/ModelNet40/sofa/train/sofa_0498.off
#   inflating: data/ModelNet40/sofa/train/sofa_0162.off
#   inflating: data/ModelNet40/sofa/train/sofa_0608.off
#   inflating: data/ModelNet40/sofa/train/sofa_0234.off
#   inflating: data/ModelNet40/sofa/train/sofa_0309.off
#   inflating: data/ModelNet40/sofa/train/sofa_0045.off
#   inflating: data/ModelNet40/sofa/train/sofa_0262.off
#   inflating: data/ModelNet40/sofa/train/sofa_0216.off
#   inflating: data/ModelNet40/sofa/train/sofa_0035.off
# ...
#   inflating: data/ModelNet40/dresser/train/dresser_0175.off
#   inflating: data/ModelNet40/dresser/train/dresser_0057.off
#   inflating: data/ModelNet40/dresser/train/dresser_0163.off
#   inflating: data/ModelNet40/dresser/train/dresser_0065.off
#   inflating: data/ModelNet40/dresser/train/dresser_0120.off
#   inflating: data/ModelNet40/dresser/train/dresser_0153.off
#   inflating: data/ModelNet40/dresser/train/dresser_0161.off
#   inflating: data/ModelNet40/dresser/train/dresser_0133.off
#   inflating: data/ModelNet40/dresser/train/dresser_0006.off
#   inflating: data/ModelNet40/dresser/train/dresser_0123.off
#   inflating: data/ModelNet40/dresser/train/dresser_0008.off
#   inflating: data/ModelNet40/dresser/train/dresser_0079.off
#   inflating: data/ModelNet40/dresser/train/dresser_0143.off
#   inflating: data/ModelNet40/dresser/train/dresser_0024.off
#   inflating: data/ModelNet40/dresser/train/dresser_0034.off
#   inflating: data/ModelNet40/dresser/train/dresser_0164.off
#   inflating: data/ModelNet40/dresser/train/dresser_0083.off
#   inflating: data/ModelNet40/dresser/train/dresser_0105.off
#   inflating: data/ModelNet40/dresser/train/dresser_0040.off
#   inflating: data/ModelNet40/dresser/train/dresser_0078.off
#   inflating: data/ModelNet40/dresser/train/dresser_0155.off
#   inflating: data/ModelNet40/dresser/train/dresser_0037.off
#   inflating: data/ModelNet40/dresser/train/dresser_0025.off
#   inflating: data/ModelNet40/dresser/train/dresser_0011.off
#   inflating: data/ModelNet40/dresser/train/dresser_0076.off
#   inflating: data/ModelNet40/dresser/train/dresser_0126.off
#   inflating: data/ModelNet40/dresser/train/dresser_0106.off
#   inflating: data/ModelNet40/dresser/train/dresser_0157.off
#   inflating: data/ModelNet40/dresser/train/dresser_0031.off
#   inflating: data/ModelNet40/dresser/train/dresser_0067.off
#   inflating: data/ModelNet40/dresser/train/dresser_0052.off
#   inflating: data/ModelNet40/dresser/train/dresser_0101.off
#   inflating: data/ModelNet40/dresser/train/dresser_0147.off
#   inflating: data/ModelNet40/dresser/train/dresser_0041.off
#   inflating: data/ModelNet40/dresser/train/dresser_0199.off
#   inflating: data/ModelNet40/dresser/train/dresser_0158.off
#   inflating: data/ModelNet40/dresser/train/dresser_0053.off
#   inflating: data/ModelNet40/dresser/train/dresser_0055.off
#   inflating: data/ModelNet40/dresser/train/dresser_0059.off
#   inflating: data/ModelNet40/dresser/train/dresser_0002.off
#   inflating: data/ModelNet40/dresser/train/dresser_0112.off
#   inflating: data/ModelNet40/dresser/train/dresser_0088.off
#   inflating: data/ModelNet40/dresser/train/dresser_0071.off
#   inflating: data/ModelNet40/dresser/train/dresser_0007.off
#   inflating: data/ModelNet40/dresser/train/dresser_0137.off
#   inflating: data/ModelNet40/dresser/train/dresser_0096.off
#   inflating: data/ModelNet40/dresser/train/dresser_0056.off
#   inflating: data/ModelNet40/dresser/train/dresser_0104.off
#   inflating: data/ModelNet40/dresser/train/dresser_0050.off
#   inflating: data/ModelNet40/dresser/train/dresser_0098.off
#   inflating: data/ModelNet40/dresser/train/dresser_0190.off
#   inflating: data/ModelNet40/dresser/train/dresser_0091.off
#   inflating: data/ModelNet40/dresser/train/dresser_0010.off
#   inflating: data/ModelNet40/dresser/train/dresser_0097.off
#   inflating: data/ModelNet40/dresser/train/dresser_0194.off
#   inflating: data/ModelNet40/dresser/train/dresser_0154.off
#   inflating: data/ModelNet40/dresser/train/dresser_0115.off
#   inflating: data/ModelNet40/dresser/train/dresser_0150.off
#   inflating: data/ModelNet40/dresser/train/dresser_0093.off
#   inflating: data/ModelNet40/dresser/train/dresser_0045.off
#   inflating: data/ModelNet40/dresser/train/dresser_0173.off
#   inflating: data/ModelNet40/dresser/train/dresser_0020.off
#   inflating: data/ModelNet40/dresser/train/dresser_0044.off
#   inflating: data/ModelNet40/dresser/train/dresser_0197.off
#   inflating: data/ModelNet40/dresser/train/dresser_0070.off
#   inflating: data/ModelNet40/dresser/train/dresser_0047.off
#   inflating: data/ModelNet40/dresser/train/dresser_0168.off
#   inflating: data/ModelNet40/dresser/train/dresser_0081.off
#   inflating: data/ModelNet40/dresser/train/dresser_0152.off
#   inflating: data/ModelNet40/dresser/train/dresser_0068.off
#   inflating: data/ModelNet40/dresser/train/dresser_0048.off
#   inflating: data/ModelNet40/dresser/train/dresser_0156.off
#   inflating: data/ModelNet40/dresser/train/dresser_0116.off
#   inflating: data/ModelNet40/dresser/train/dresser_0174.off
#   inflating: data/ModelNet40/dresser/train/dresser_0145.off
#   inflating: data/ModelNet40/dresser/train/dresser_0073.off
#   inflating: data/ModelNet40/dresser/train/dresser_0159.off
#   inflating: data/ModelNet40/dresser/train/dresser_0075.off
#   inflating: data/ModelNet40/dresser/train/dresser_0121.off
#   inflating: data/ModelNet40/dresser/train/dresser_0172.off
#   inflating: data/ModelNet40/dresser/train/dresser_0082.off
#   inflating: data/ModelNet40/dresser/train/dresser_0181.off
#   inflating: data/ModelNet40/dresser/train/dresser_0084.off
#   inflating: data/ModelNet40/dresser/train/dresser_0142.off
#   inflating: data/ModelNet40/dresser/train/dresser_0030.off
#   inflating: data/ModelNet40/dresser/train/dresser_0127.off
#   inflating: data/ModelNet40/dresser/train/dresser_0086.off
#   inflating: data/ModelNet40/dresser/train/dresser_0134.off
#   inflating: data/ModelNet40/dresser/train/dresser_0100.off
#   inflating: data/ModelNet40/dresser/train/dresser_0182.off
#   inflating: data/ModelNet40/dresser/train/dresser_0165.off
#   inflating: data/ModelNet40/dresser/train/dresser_0074.off
#   inflating: data/ModelNet40/dresser/train/dresser_0117.off
#   inflating: data/ModelNet40/dresser/train/dresser_0054.off
#   inflating: data/ModelNet40/dresser/train/dresser_0080.off
#   inflating: data/ModelNet40/dresser/train/dresser_0148.off
#   inflating: data/ModelNet40/dresser/train/dresser_0102.off
#   inflating: data/ModelNet40/dresser/train/dresser_0160.off
#   inflating: data/ModelNet40/dresser/train/dresser_0200.off
#   inflating: data/ModelNet40/dresser/train/dresser_0195.off
#   inflating: data/ModelNet40/dresser/train/dresser_0063.off
#   inflating: data/ModelNet40/dresser/train/dresser_0196.off
#   inflating: data/ModelNet40/dresser/train/dresser_0033.off
#   inflating: data/ModelNet40/dresser/train/dresser_0192.off
#   inflating: data/ModelNet40/dresser/train/dresser_0130.off
#   inflating: data/ModelNet40/dresser/train/dresser_0036.off
#   inflating: data/ModelNet40/dresser/train/dresser_0012.off
#   inflating: data/ModelNet40/dresser/train/dresser_0042.off
#   inflating: data/ModelNet40/dresser/train/dresser_0017.off
#   inflating: data/ModelNet40/dresser/train/dresser_0136.off
#   inflating: data/ModelNet40/dresser/train/dresser_0028.off
#   inflating: data/ModelNet40/dresser/train/dresser_0005.off
#   inflating: data/ModelNet40/dresser/train/dresser_0060.off
#   inflating: data/ModelNet40/dresser/train/dresser_0169.off
#   inflating: data/ModelNet40/dresser/train/dresser_0177.off
#   inflating: data/ModelNet40/dresser/train/dresser_0166.off
#   inflating: data/ModelNet40/dresser/train/dresser_0108.off
#   inflating: data/ModelNet40/dresser/train/dresser_0144.off
#   inflating: data/ModelNet40/dresser/train/dresser_0114.off
#   inflating: data/ModelNet40/dresser/train/dresser_0129.off
#   inflating: data/ModelNet40/dresser/train/dresser_0095.off
#   inflating: data/ModelNet40/dresser/train/dresser_0138.off
#   inflating: data/ModelNet40/dresser/train/dresser_0135.off
#   inflating: data/ModelNet40/dresser/train/dresser_0085.off
#   inflating: data/ModelNet40/dresser/train/dresser_0003.off
#   inflating: data/ModelNet40/dresser/train/dresser_0170.off
#   inflating: data/ModelNet40/dresser/train/dresser_0146.off
#   inflating: data/ModelNet40/dresser/train/dresser_0186.off
#   inflating: data/ModelNet40/dresser/train/dresser_0107.off
#   inflating: data/ModelNet40/dresser/train/dresser_0185.off
#   inflating: data/ModelNet40/dresser/train/dresser_0124.off
#   inflating: data/ModelNet40/dresser/train/dresser_0119.off
#   inflating: data/ModelNet40/dresser/train/dresser_0139.off
#   inflating: data/ModelNet40/dresser/train/dresser_0090.off
#   inflating: data/ModelNet40/dresser/train/dresser_0184.off
#   inflating: data/ModelNet40/dresser/train/dresser_0019.off
#   inflating: data/ModelNet40/dresser/train/dresser_0051.off
#   inflating: data/ModelNet40/dresser/train/dresser_0151.off
#   inflating: data/ModelNet40/dresser/train/dresser_0118.off
#   inflating: data/ModelNet40/dresser/train/dresser_0039.off
#   inflating: data/ModelNet40/dresser/train/dresser_0094.off
#   inflating: data/ModelNet40/dresser/train/dresser_0018.off
#   inflating: data/ModelNet40/dresser/train/dresser_0046.off
#   inflating: data/ModelNet40/dresser/train/dresser_0061.off
#   inflating: data/ModelNet40/dresser/train/dresser_0183.off
#   inflating: data/ModelNet40/dresser/train/dresser_0092.off
#   inflating: data/ModelNet40/dresser/train/dresser_0087.off
#   inflating: data/ModelNet40/dresser/train/dresser_0029.off
#   inflating: data/ModelNet40/dresser/train/dresser_0058.off
#   inflating: data/ModelNet40/dresser/train/dresser_0035.off
#   inflating: data/ModelNet40/dresser/train/dresser_0026.off
#   inflating: data/ModelNet40/dresser/train/dresser_0113.off
#   inflating: data/ModelNet40/dresser/train/dresser_0109.off
#   inflating: data/ModelNet40/dresser/train/dresser_0141.off
#   inflating: data/ModelNet40/dresser/train/dresser_0015.off
#   inflating: data/ModelNet40/dresser/train/dresser_0004.off
#   inflating: data/ModelNet40/dresser/train/dresser_0021.off
#   inflating: data/ModelNet40/dresser/train/dresser_0189.off
#   inflating: data/ModelNet40/dresser/train/dresser_0162.off
#   inflating: data/ModelNet40/dresser/train/dresser_0009.off
#   inflating: data/ModelNet40/dresser/train/dresser_0125.off
#   inflating: data/ModelNet40/dresser/train/dresser_0103.off
#   inflating: data/ModelNet40/dresser/train/dresser_0198.off
#   inflating: data/ModelNet40/dresser/train/dresser_0099.off
#   inflating: data/ModelNet40/dresser/train/dresser_0089.off
#   inflating: data/ModelNet40/dresser/train/dresser_0013.off
#   inflating: data/ModelNet40/dresser/train/dresser_0064.off
#   inflating: data/ModelNet40/dresser/train/dresser_0014.off
#   inflating: data/ModelNet40/dresser/train/dresser_0110.off
#   inflating: data/ModelNet40/dresser/train/dresser_0178.off
#   inflating: data/ModelNet40/dresser/train/dresser_0077.off
#   inflating: data/ModelNet40/dresser/train/dresser_0180.off
#    creating: data/ModelNet40/dresser/test/
#   inflating: data/ModelNet40/dresser/test/dresser_0284.off
#   inflating: data/ModelNet40/dresser/test/dresser_0224.off
#   inflating: data/ModelNet40/dresser/test/dresser_0266.off
#   inflating: data/ModelNet40/dresser/test/dresser_0270.off
#   inflating: data/ModelNet40/dresser/test/dresser_0253.off
#   inflating: data/ModelNet40/dresser/test/dresser_0265.off
#   inflating: data/ModelNet40/dresser/test/dresser_0228.off
#   inflating: data/ModelNet40/dresser/test/dresser_0271.off
#   inflating: data/ModelNet40/dresser/test/dresser_0215.off
#   inflating: data/ModelNet40/dresser/test/dresser_0260.off
#   inflating: data/ModelNet40/dresser/test/dresser_0243.off
#   inflating: data/ModelNet40/dresser/test/dresser_0207.off
#   inflating: data/ModelNet40/dresser/test/dresser_0211.off
#   inflating: data/ModelNet40/dresser/test/dresser_0249.off
#   inflating: data/ModelNet40/dresser/test/dresser_0221.off
#   inflating: data/ModelNet40/dresser/test/dresser_0202.off
#   inflating: data/ModelNet40/dresser/test/dresser_0263.off
#   inflating: data/ModelNet40/dresser/test/dresser_0231.off
#   inflating: data/ModelNet40/dresser/test/dresser_0242.off
#   inflating: data/ModelNet40/dresser/test/dresser_0220.off
#   inflating: data/ModelNet40/dresser/test/dresser_0274.off
#   inflating: data/ModelNet40/dresser/test/dresser_0236.off
#   inflating: data/ModelNet40/dresser/test/dresser_0201.off
#   inflating: data/ModelNet40/dresser/test/dresser_0237.off
#   inflating: data/ModelNet40/dresser/test/dresser_0281.off
#   inflating: data/ModelNet40/dresser/test/dresser_0257.off
#   inflating: data/ModelNet40/dresser/test/dresser_0280.off
#   inflating: data/ModelNet40/dresser/test/dresser_0206.off
#   inflating: data/ModelNet40/dresser/test/dresser_0275.off
#   inflating: data/ModelNet40/dresser/test/dresser_0216.off
#   inflating: data/ModelNet40/dresser/test/dresser_0235.off
#   inflating: data/ModelNet40/dresser/test/dresser_0234.off
#   inflating: data/ModelNet40/dresser/test/dresser_0225.off
#   inflating: data/ModelNet40/dresser/test/dresser_0247.off
#   inflating: data/ModelNet40/dresser/test/dresser_0245.off
#   inflating: data/ModelNet40/dresser/test/dresser_0248.off
#   inflating: data/ModelNet40/dresser/test/dresser_0229.off
#   inflating: data/ModelNet40/dresser/test/dresser_0222.off
#   inflating: data/ModelNet40/dresser/test/dresser_0258.off
#   inflating: data/ModelNet40/dresser/test/dresser_0226.off
#   inflating: data/ModelNet40/dresser/test/dresser_0238.off
#   inflating: data/ModelNet40/dresser/test/dresser_0205.off
#   inflating: data/ModelNet40/dresser/test/dresser_0209.off
#   inflating: data/ModelNet40/dresser/test/dresser_0213.off
#   inflating: data/ModelNet40/dresser/test/dresser_0267.off
#   inflating: data/ModelNet40/dresser/test/dresser_0246.off
#   inflating: data/ModelNet40/dresser/test/dresser_0261.off
#   inflating: data/ModelNet40/dresser/test/dresser_0239.off
#   inflating: data/ModelNet40/dresser/test/dresser_0218.off
#   inflating: data/ModelNet40/dresser/test/dresser_0272.off
#   inflating: data/ModelNet40/dresser/test/dresser_0259.off
#   inflating: data/ModelNet40/dresser/test/dresser_0268.off
#   inflating: data/ModelNet40/dresser/test/dresser_0232.off
#   inflating: data/ModelNet40/dresser/test/dresser_0264.off
#   inflating: data/ModelNet40/dresser/test/dresser_0250.off
#   inflating: data/ModelNet40/dresser/test/dresser_0203.off
#   inflating: data/ModelNet40/dresser/test/dresser_0277.off
#   inflating: data/ModelNet40/dresser/test/dresser_0283.off
#   inflating: data/ModelNet40/dresser/test/dresser_0279.off
#   inflating: data/ModelNet40/dresser/test/dresser_0285.off
#   inflating: data/ModelNet40/dresser/test/dresser_0252.off
#   inflating: data/ModelNet40/dresser/test/dresser_0256.off
#   inflating: data/ModelNet40/dresser/test/dresser_0217.off
#   inflating: data/ModelNet40/dresser/test/dresser_0212.off
#   inflating: data/ModelNet40/dresser/test/dresser_0208.off
#   inflating: data/ModelNet40/dresser/test/dresser_0219.off
#   inflating: data/ModelNet40/dresser/test/dresser_0273.off
#   inflating: data/ModelNet40/dresser/test/dresser_0254.off
#   inflating: data/ModelNet40/dresser/test/dresser_0233.off
#   inflating: data/ModelNet40/dresser/test/dresser_0241.off
#   inflating: data/ModelNet40/dresser/test/dresser_0214.off
#   inflating: data/ModelNet40/dresser/test/dresser_0276.off
#   inflating: data/ModelNet40/dresser/test/dresser_0244.off
#   inflating: data/ModelNet40/dresser/test/dresser_0230.off
#   inflating: data/ModelNet40/dresser/test/dresser_0204.off
#   inflating: data/ModelNet40/dresser/test/dresser_0227.off
#   inflating: data/ModelNet40/dresser/test/dresser_0262.off
#   inflating: data/ModelNet40/dresser/test/dresser_0240.off
#   inflating: data/ModelNet40/dresser/test/dresser_0251.off
#   inflating: data/ModelNet40/dresser/test/dresser_0269.off
#   inflating: data/ModelNet40/dresser/test/dresser_0223.off
#   inflating: data/ModelNet40/dresser/test/dresser_0286.off
#   inflating: data/ModelNet40/dresser/test/dresser_0282.off
#   inflating: data/ModelNet40/dresser/test/dresser_0255.off
#   inflating: data/ModelNet40/dresser/test/dresser_0210.off
#   inflating: data/ModelNet40/dresser/test/dresser_0278.off

# %%
pip install trimesh
# Out:
# Requirement already satisfied: trimesh in /usr/local/lib/python3.10/dist-packages (4.4.9)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from trimesh) (1.26.4)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import trimesh
from torchvision import transforms

# Set device to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class PointCloudDataset(Dataset):
    def __init__(self, root_dir, split='train', transform=None):
        self.root_dir = root_dir
        self.split = split
        self.transform = transform
        self.file_paths = []
        self.labels = []
        self.categories = sorted(os.listdir(root_dir))
        self.category_to_idx = {category: idx for idx, category in enumerate(self.categories)}

        self.load_data()

    def load_data(self):
        for category in self.categories:
            category_dir = os.path.join(self.root_dir, category, self.split)
            if os.path.isdir(category_dir):
                for file in os.listdir(category_dir):
                    if file.endswith('.off'):
                        self.file_paths.append(os.path.join(category_dir, file))
                        self.labels.append(self.category_to_idx[category])

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        label = self.labels[idx]

        mesh = trimesh.load(file_path)
        point_cloud = mesh.sample(768)  # Increased to 768 points

        if self.transform:
            point_cloud = self.transform(point_cloud)

        point_cloud = point_cloud - point_cloud.mean(axis=0)
        point_cloud = point_cloud / np.max(np.linalg.norm(point_cloud, axis=1))

        return torch.from_numpy(point_cloud).float().transpose(0, 1), label

# %%
class RandomScale:
    def __init__(self, scale_range=(0.8, 1.2)):
        self.scale_range = scale_range

    def __call__(self, point_cloud):
        scale = np.random.uniform(*self.scale_range)
        return point_cloud * scale

class JitterPoints:
    def __init__(self, sigma=0.01, clip=0.05):
        self.sigma = sigma
        self.clip = clip

    def __call__(self, point_cloud):
        jittered_data = np.clip(self.sigma * np.random.randn(*point_cloud.shape), -self.clip, self.clip)
        return point_cloud + jittered_data

transform = transforms.Compose([RandomRotation(), RandomScale(), JitterPoints()])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
import os
import trimesh
from torchvision import transforms
from tqdm import tqdm  # For progress bars

# %%
batch_size = 16

train_dataset = PointCloudDataset(root_dir='data/ModelNet40', split='train', transform=transform)
test_dataset = PointCloudDataset(root_dir='data/ModelNet40', split='test', transform=None)

# Using only 1000 samples for training and 200 for testing (for debugging)
train_dataset, _ = random_split(train_dataset, [1000, len(train_dataset) - 1000])
test_dataset, _ = random_split(test_dataset, [200, len(test_dataset) - 200])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class PointNet(nn.Module):
    def __init__(self, num_classes):
        super(PointNet, self).__init__()
        self.conv1 = nn.Conv1d(3, 64, kernel_size=1)
        self.bn1 = nn.BatchNorm1d(64)  # Batch Normalization
        self.conv2 = nn.Conv1d(64, 128, kernel_size=1)
        self.bn2 = nn.BatchNorm1d(128)
        self.conv3 = nn.Conv1d(128, 512, kernel_size=1)  # Increased to 512 channels
        self.bn3 = nn.BatchNorm1d(512)

        self.fc1 = nn.Linear(512, 256)
        self.bn4 = nn.BatchNorm1d(256)
        self.fc2 = nn.Linear(256, 128)
        self.bn5 = nn.BatchNorm1d(128)
        self.fc3 = nn.Linear(128, num_classes)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.3)
        self.log_softmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.relu(self.bn2(self.conv2(x)))
        x = self.relu(self.bn3(self.conv3(x)))
        x = torch.max(x, 2)[0]  # Max pooling
        x = self.relu(self.bn4(self.fc1(x)))
        x = self.dropout(self.relu(self.bn5(self.fc2(x))))
        x = self.fc3(x)
        return self.log_softmax(x)

# %%
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    correct = 0
    total = 0

    for data, target in tqdm(loader, desc="Training"):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        pred = output.argmax(dim=1)
        correct += pred.eq(target).sum().item()
        total += target.size(0)

    return total_loss / len(loader), correct / total

def test(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for data, target in tqdm(loader, desc="Testing"):
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            pred = output.argmax(dim=1)
            correct += pred.eq(target).sum().item()
            total += target.size(0)

    return total_loss / len(loader), correct / total

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = PointNet(num_classes=len(train_dataset.dataset.categories)).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)  # Reduced learning rate, added weight decay
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)
criterion = nn.CrossEntropyLoss()

epochs = 20
for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')

    train_loss, train_acc = train(model, train_loader, optimizer, criterion, device)
    test_loss, test_acc = test(model, test_loader, criterion, device)
    scheduler.step()

    print(f'Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}')
# Out:
# Epoch 1/20
# Training: 100%|██████████| 63/63 [02:45<00:00,  2.63s/it]
# Testing: 100%|██████████| 13/13 [00:28<00:00,  2.22s/it]
# Epoch 1/20 | Train Loss: 3.1588 | Train Acc: 0.2160 | Test Loss: 2.6465 | Test Acc: 0.2550
# Epoch 2/20
# Training: 100%|██████████| 63/63 [02:40<00:00,  2.54s/it]
# Testing: 100%|██████████| 13/13 [00:28<00:00,  2.19s/it]
# Epoch 2/20 | Train Loss: 2.4686 | Train Acc: 0.3840 | Test Loss: 2.4841 | Test Acc: 0.3650
# Epoch 3/20
# Training: 100%|██████████| 63/63 [02:39<00:00,  2.53s/it]
# Testing: 100%|██████████| 13/13 [00:27<00:00,  2.14s/it]
# Epoch 3/20 | Train Loss: 2.1402 | Train Acc: 0.4680 | Test Loss: 2.1694 | Test Acc: 0.4150
# Epoch 4/20
# Training: 100%|██████████| 63/63 [02:39<00:00,  2.53s/it]
# Testing: 100%|██████████| 13/13 [00:27<00:00,  2.15s/it]
# Epoch 4/20 | Train Loss: 1.9088 | Train Acc: 0.5160 | Test Loss: 2.0333 | Test Acc: 0.4350
# Epoch 5/20
# Training: 100%|██████████| 63/63 [02:40<00:00,  2.55s/it]
# Testing: 100%|██████████| 13/13 [00:28<00:00,  2.20s/it]
# Epoch 5/20 | Train Loss: 1.7501 | Train Acc: 0.5500 | Test Loss: 1.7743 | Test Acc: 0.4950
# Epoch 6/20
# Training: 100%|██████████| 63/63 [02:39<00:00,  2.53s/it]
# Testing: 100%|██████████| 13/13 [00:28<00:00,  2.16s/it]
# Epoch 6/20 | Train Loss: 1.5579 | Train Acc: 0.5800 | Test Loss: 1.7697 | Test Acc: 0.4550
# Epoch 7/20
# Training: 100%|██████████| 63/63 [02:39<00:00,  2.53s/it]
# Testing: 100%|██████████| 13/13 [00:27<00:00,  2.13s/it]
# Epoch 7/20 | Train Loss: 1.4479 | Train Acc: 0.6120 | Test Loss: 1.5384 | Test Acc: 0.6000
# Epoch 8/20
# Training: 100%|██████████| 63/63 [02:38<00:00,  2.51s/it]
# Testing: 100%|██████████| 13/13 [00:27<00:00,  2.12s/it]
# Epoch 8/20 | Train Loss: 1.3583 | Train Acc: 0.6450 | Test Loss: 1.5261 | Test Acc: 0.6050
# Epoch 9/20
# Training: 100%|██████████| 63/63 [02:38<00:00,  2.52s/it]
# Testing: 100%|██████████| 13/13 [00:28<00:00,  2.18s/it]
# Epoch 9/20 | Train Loss: 1.2690 | Train Acc: 0.6590 | Test Loss: 1.5558 | Test Acc: 0.5800
# Epoch 10/20
